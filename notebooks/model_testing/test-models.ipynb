# %%
from kaggle_secrets import UserSecretsClient # see https://www.kaggle.com/discussions/product-feedback/114053 for more info
import sys

user_secrets = UserSecretsClient()
personal_token = user_secrets.get_secret("git-pat")

# %%
# !git clone https://{personal_token}@github.com/JulianRodd/MLiP_group_10_task1_HMS.git # for generic 
branch = "new-modelz"
# !git clone -b {branch} https://{personal_token}@github.com/JulianRodd/MLiP_group_10_task1_HMS.git # for branch
    
sys.path.insert(1, "/kaggle/working/MLiP_group_10_task1_HMS") # pos 1 to avoid conflicts
# Out:
# Cloning into 'MLiP_group_10_task1_HMS'...
# remote: Enumerating objects: 404, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 404 (delta 52), reused 72 (delta 30), pack-reused 296
# Receiving objects: 100% (404/404), 662.40 KiB | 7.12 MiB/s, done.
# Resolving deltas: 100% (228/228), done.

# %%
import os


os.chdir('/kaggle/working/MLiP_group_10_task1_HMS')
# !git checkout failures

# %%
# !git pull
# Out:
# Already up to date.

# %%
from generics import Paths 


for attr in dir(Paths):
    if attr.startswith("__"):
            continue
    
    path = getattr(Paths, attr)
    print(f"{attr}: {path}")
    
    if path.startswith("./"):
        path = path[1:]

    path = path.replace("/data", "")
    
    if not path.startswith('/kaggle/input/'):
        path = '/kaggle/working/'+path
    path= path.replace('//', '/')
        
    if not os.path.exists(path):
        os.makedirs(path)
    
    setattr(Paths, attr, path)
    path = getattr(Paths, attr)
    print(f"{attr}: {path}")
# Out:
# BEST_MODEL_CHECKPOINTS: ./checkpoints/best_models/
# BEST_MODEL_CHECKPOINTS: /kaggle/working/checkpoints/best_models/
# CACHE_PATH_READ: ./data/cache/
# CACHE_PATH_READ: /kaggle/working/cache/
# CACHE_PATH_WRITE: ./data/cache/
# CACHE_PATH_WRITE: /kaggle/working/cache/
# LOG_PATH: ./logs/
# LOG_PATH: /kaggle/working/logs/
# OTHER_MODEL_CHECKPOINTS: ./checkpoints/other_models/
# OTHER_MODEL_CHECKPOINTS: /kaggle/working/checkpoints/other_models/
# PRE_LOADED_EEGS: ./data/kaggle/input/brain-eeg-spectrograms/eeg_specs.npy
# PRE_LOADED_EEGS: /kaggle/input/brain-eeg-spectrograms/eeg_specs.npy
# PRE_LOADED_SPECTROGRAMS: ./data/kaggle/input/brain-spectrograms/specs.npy
# PRE_LOADED_SPECTROGRAMS: /kaggle/input/brain-spectrograms/specs.npy
# TENSORBOARD: ./tensorboard/
# TENSORBOARD: /kaggle/working/tensorboard/
# TENSORBOARD_DATASETS: ./tensorboard/datasets/
# TENSORBOARD_DATASETS: /kaggle/working/tensorboardsets/
# TENSORBOARD_INFERENCE: ./tensorboard/inference/
# TENSORBOARD_INFERENCE: /kaggle/working/tensorboard/inference/
# TENSORBOARD_MODELS: ./tensorboard/models/
# TENSORBOARD_MODELS: /kaggle/working/tensorboard/models/
# TENSORBOARD_TRAINING: ./tensorboard/training/
# TENSORBOARD_TRAINING: /kaggle/working/tensorboard/training/
# TEST_CSV: ./data/kaggle/input/hms-harmful-brain-activity-classification/test.csv
# TEST_CSV: /kaggle/input/hms-harmful-brain-activity-classification/test.csv
# TEST_EEGS: ./data/kaggle/input/hms-harmful-brain-activity-classification/test_eegs/
# TEST_EEGS: /kaggle/input/hms-harmful-brain-activity-classification/test_eegs/
# TEST_SPECTROGRAMS: ./data/kaggle/input/hms-harmful-brain-activity-classification/test_spectrograms/
# TEST_SPECTROGRAMS: /kaggle/input/hms-harmful-brain-activity-classification/test_spectrograms/
# TRAIN_CSV: ./data/kaggle/input/hms-harmful-brain-activity-classification/train.csv
# TRAIN_CSV: /kaggle/input/hms-harmful-brain-activity-classification/train.csv
# TRAIN_EEGS: ./data/kaggle/input/hms-harmful-brain-activity-classification/train_eegs/
# TRAIN_EEGS: /kaggle/input/hms-harmful-brain-activity-classification/train_eegs/
# TRAIN_SPECTROGRAMS: ./data/kaggle/input/hms-harmful-brain-activity-classification/train_spectrograms/
# TRAIN_SPECTROGRAMS: /kaggle/input/hms-harmful-brain-activity-classification/train_spectrograms/

# %%
# !git pull
from importlib import reload 
import main_model_testing
import torch
from generics import Generics

# reload(main_shufflenet)

Generics.DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # does not work with CPU 
main_model_testing.main()
# Out:
# Already up to date.
# 2024-02-29 09:21:53.169615: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-29 09:21:53.169714: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-29 09:21:53.300520: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-29 09:22:07,628 - main - INFO - Training model ResNetBase with data loader SmallBaseConfig
# 2024-02-29 09:22:08,075 - data_loader.log - INFO - Processing and caching new dataset
# Train non-overlapp eeg_id shape: (17089, 12)
# 2024-02-29 09:24:30,382 - data_loader.log - INFO - Dataset cached at SmallBaseConfig_100_train.npz
# 2024-02-29 09:24:30,383 - data_loader.log - INFO - Dataset loaded: train mode, 80 samples, with config SmallBaseConfig
# 2024-02-29 09:24:30,387 - data_loader.log - INFO - Processing and caching new dataset
# 2024-02-29 09:24:30,387 - data_loader.log - INFO - Processing and caching new dataset
# 2024-02-29 09:25:25,796 - data_loader.log - INFO - Dataset cached at SmallBaseConfig_100_val.npz
# 2024-02-29 09:25:25,796 - data_loader.log - INFO - Dataset cached at SmallBaseConfig_100_val.npz
# 2024-02-29 09:25:25,798 - data_loader.log - INFO - Dataset loaded: val mode, 20 samples, with config SmallBaseConfig
# 2024-02-29 09:25:25,798 - data_loader.log - INFO - Dataset loaded: val mode, 20 samples, with config SmallBaseConfig
# 2024-02-29 09:25:25,853 - models/models.CustomModel - INFO - Using device: cuda
# Dataset Summary:
# Mode: train
# Total Samples: 80
# Unique Patients: 80
# Unique EEGs: 80
# Unique Spectrograms: 80
# Augmentation: Disabled
# Label Distribution:
# seizure_vote    26.285294
# lpd_vote         3.955459
# gpd_vote         1.762500
# lrda_vote        6.229483
# grda_vote       14.759703
# other_vote      27.007560
# dtype: float64
#
# Vote Statistics:
#       seizure_vote  lpd_vote  gpd_vote  lrda_vote  grda_vote  other_vote
# mean      0.328566  0.049443  0.022031   0.077869   0.184496    0.337595
# var       0.200456  0.030615  0.011706   0.063723   0.138927    0.182441
# Spectrograms Loaded: 80
# EEG Spectrograms Loaded: 80
#
# Configuration Summary:
# +--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+
# | Configuration                  | Value                                                                                                                                |
# +--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+
# | APPLY_ICA_EEG_SPECTROGRAMS     | False                                                                                                                                |
# | APPLY_ICA_RAW_EEG              | False                                                                                                                                |
# | APPLY_MSPCA_EEG_SPECTROGRAMS   | False                                                                                                                                |
# | APPLY_MSPCA_RAW_EEG            | False                                                                                                                                |
# | BATCH_SIZE_TEST                | 4                                                                                                                                    |
# | BATCH_SIZE_TRAIN               | 8                                                                                                                                    |
# | BATCH_SIZE_VAL                 | 4                                                                                                                                    |
# | DROP_LAST                      | True                                                                                                                                 |
# | FEATS                          | [['Fp1', 'F7', 'T3', 'T5', 'O1'], ['Fp1', 'F3', 'C3', 'P3', 'O1'], ['Fp2', 'F8', 'T4', 'T6', 'O2'], ['Fp2', 'F4', 'C4', 'P4', 'O2']] |
# | FILTER_BY_AGREEMENT            | False                                                                                                                                |
# | FILTER_BY_AGREEMENT_MIN        | 50                                                                                                                                   |
# | FILTER_BY_AGREEMENT_ON_VAL     | False                                                                                                                                |
# | FILTER_BY_ANNOTATOR            | False                                                                                                                                |
# | FILTER_BY_ANNOTATOR_MAX        | 22                                                                                                                                   |
# | FILTER_BY_ANNOTATOR_MIN        | 7                                                                                                                                    |
# | FILTER_BY_ANNOTATOR_ON_VAL     | False                                                                                                                                |
# | NAME                           | SmallBaseConfig                                                                                                                      |
# | NAMES                          | ['LL', 'LP', 'RP', 'RR']                                                                                                             |
# | NORMALIZE_EEG_SPECTROGRAMS     | False                                                                                                                                |
# | NORMALIZE_INDIVIDUALLY         | True                                                                                                                                 |
# | NORMALIZE_RAW_EEG              | False                                                                                                                                |
# | NUM_WORKERS                    | 0                                                                                                                                    |
# | N_COMPONENTS                   | 4                                                                                                                                    |
# | PIN_MEMORY                     | True                                                                                                                                 |
# | SHUFFLE_TRAIN                  | True                                                                                                                                 |
# | SUBSET_SAMPLE_COUNT            | 100                                                                                                                                  |
# | USE_PRELOADED_EEG_SPECTROGRAMS | True                                                                                                                                 |
# | USE_PRELOADED_SPECTROGRAMS     | True                                                                                                                                 |
# | USE_WAVELET                    | None                                                                                                                                 |
# | VAL_SPLIT_RATIO                | 0.2                                                                                                                                  |
# +--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+
# Dataset Summary:
# Mode: val
# Total Samples: 20
# Unique Patients: 20
# Unique EEGs: 20
# Unique Spectrograms: 20
# Spectrograms Loaded: 20
# EEG Spectrograms Loaded: 20
#
# Configuration Summary:
# +--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+
# | Configuration                  | Value                                                                                                                                |
# +--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+
# | APPLY_ICA_EEG_SPECTROGRAMS     | False                                                                                                                                |
# | APPLY_ICA_RAW_EEG              | False                                                                                                                                |
# | APPLY_MSPCA_EEG_SPECTROGRAMS   | False                                                                                                                                |
# | APPLY_MSPCA_RAW_EEG            | False                                                                                                                                |
# | BATCH_SIZE_TEST                | 4                                                                                                                                    |
# | BATCH_SIZE_TRAIN               | 8                                                                                                                                    |
# | BATCH_SIZE_VAL                 | 4                                                                                                                                    |
# | DROP_LAST                      | True                                                                                                                                 |
# | FEATS                          | [['Fp1', 'F7', 'T3', 'T5', 'O1'], ['Fp1', 'F3', 'C3', 'P3', 'O1'], ['Fp2', 'F8', 'T4', 'T6', 'O2'], ['Fp2', 'F4', 'C4', 'P4', 'O2']] |
# | FILTER_BY_AGREEMENT            | False                                                                                                                                |
# | FILTER_BY_AGREEMENT_MIN        | 50                                                                                                                                   |
# | FILTER_BY_AGREEMENT_ON_VAL     | False                                                                                                                                |
# | FILTER_BY_ANNOTATOR            | False                                                                                                                                |
# | FILTER_BY_ANNOTATOR_MAX        | 22                                                                                                                                   |
# | FILTER_BY_ANNOTATOR_MIN        | 7                                                                                                                                    |
# | FILTER_BY_ANNOTATOR_ON_VAL     | False                                                                                                                                |
# | NAME                           | SmallBaseConfig                                                                                                                      |
# | NAMES                          | ['LL', 'LP', 'RP', 'RR']                                                                                                             |
# | NORMALIZE_EEG_SPECTROGRAMS     | False                                                                                                                                |
# | NORMALIZE_INDIVIDUALLY         | True                                                                                                                                 |
# | NORMALIZE_RAW_EEG              | False                                                                                                                                |
# | NUM_WORKERS                    | 0                                                                                                                                    |
# | N_COMPONENTS                   | 4                                                                                                                                    |
# | PIN_MEMORY                     | True                                                                                                                                 |
# | SHUFFLE_TRAIN                  | True                                                                                                                                 |
# | SUBSET_SAMPLE_COUNT            | 100                                                                                                                                  |
# | USE_PRELOADED_EEG_SPECTROGRAMS | True                                                                                                                                 |
# | USE_PRELOADED_SPECTROGRAMS     | True                                                                                                                                 |
# | USE_WAVELET                    | None                                                                                                                                 |
# | VAL_SPLIT_RATIO                | 0.2                                                                                                                                  |
# +--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+
# Downloading: "https://github.com/pytorch/vision/zipball/v0.10.0" to /root/.cache/torch/hub/v0.10.0.zip
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 171MB/s]
# 2024-02-29 09:25:28,823 - models/models.CustomModel - INFO - resnet50 initialized with config ResNetBase
# 2024-02-29 09:25:28,828 - utils.training_utils - INFO - Epoch 1/10
# Train:  10%|█         | 1/10 [00:02<00:23,  2.65s/train_batch]
# Epoch: [1][0/10] Elapsed 0m 2s (remain 0m 23s) Loss: 1.7854 Grad: 11.5184  LR: 0.00180589
# Train: 100%|██████████| 10/10 [00:15<00:00,  1.52s/train_batch]
# Epoch: [1][9/10] Elapsed 0m 14s (remain 0m 0s) Loss: 2.3481 Grad: 8.6733  LR: 0.00990194
# Validation:  40%|████      | 2/5 [00:00<00:00, 12.65valid_batch/s]
# 22567116800.0
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 22567116800.0000
# 21078147072.0
# 22395329877.333332
# Validation: 100%|██████████| 5/5 [00:00<00:00, 13.80valid_batch/s]
# 2024-02-29 09:25:44,386 - utils.training_utils - INFO - Average Training Loss: 2.3481
# 2024-02-29 09:25:44,387 - utils.training_utils - INFO - Average Validation Loss: 24101436620.8000
# 20095452160.0
# 24101436620.8
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 24101436620.8000
# 2024-02-29 09:25:44,569 - utils.training_utils - INFO - Epoch 2/10
# Train:  10%|█         | 1/10 [00:01<00:12,  1.42s/train_batch]
# Epoch: [2][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.2407 Grad: 17.2132  LR: 0.00986669
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.40s/train_batch]
# Epoch: [2][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.5049 Grad: 4.4796  LR: 0.00931656
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.67valid_batch/s]
# 62254.5703125
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 62254.5703
# 58367.412109375
# 58679.389322916664
# 57693.8388671875
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.71valid_batch/s]
# 2024-02-29 09:25:58,882 - utils.training_utils - INFO - Average Training Loss: 1.5049
# 2024-02-29 09:25:58,883 - utils.training_utils - INFO - Average Validation Loss: 59170.1773
# 59170.17734375
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 59170.1773
# 2024-02-29 09:25:59,294 - utils.training_utils - INFO - Epoch 3/10
# Train:  10%|█         | 1/10 [00:01<00:13,  1.46s/train_batch]
# Epoch: [3][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.9903 Grad: 7.3580  LR: 0.00923078
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.40s/train_batch]
# Epoch: [3][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.4806 Grad: 1.8479  LR: 0.00826362
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.35valid_batch/s]
# 14149.96484375
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 14149.9648
# 16764.0
# 15733.279296875
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.55valid_batch/s]
# 2024-02-29 09:26:13,640 - utils.training_utils - INFO - Average Training Loss: 1.4806
# 2024-02-29 09:26:13,641 - utils.training_utils - INFO - Average Validation Loss: 13495.1293
# 14800.6064453125
# 13495.129296875
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 13495.1293
# 2024-02-29 09:26:13,902 - utils.training_utils - INFO - Epoch 4/10
# Train:  10%|█         | 1/10 [00:01<00:12,  1.43s/train_batch]
# Epoch: [4][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.2090 Grad: 1.8215  LR: 0.00813663
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.39s/train_batch]
# Epoch: [4][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.4734 Grad: 1.3394  LR: 0.00685724
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.40s/train_batch]/s]
# Epoch: [5][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.3763 Grad: 1.0178  LR: 0.00524982
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.49valid_batch/s]
# 185.15728759765625
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 185.1573
# 128.7618064880371
# 107.42409769694011
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.63valid_batch/s]
# 2024-02-29 09:26:42,769 - utils.training_utils - INFO - Average Training Loss: 1.3763
# 2024-02-29 09:26:42,770 - utils.training_utils - INFO - Average Validation Loss: 132.2056
# 123.48427200317383
# 132.20555114746094
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 132.2056
# 2024-02-29 09:26:43,032 - utils.training_utils - INFO - Epoch 6/10
# Train:  10%|█         | 1/10 [00:01<00:12,  1.43s/train_batch]
# Epoch: [6][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.4596 Grad: 4.0452  LR: 0.00508464
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.40s/train_batch]
# Epoch: [6][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.4540 Grad: 2.5276  LR: 0.00361554
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.58valid_batch/s]
# 9.396666526794434
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 9.3967
# 14.550276279449463
# 15.308506965637207
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.50valid_batch/s]
# 2024-02-29 09:26:57,347 - utils.training_utils - INFO - Average Training Loss: 1.4540
# 2024-02-29 09:26:57,348 - utils.training_utils - INFO - Average Validation Loss: 11.5170
# 11.71826447546482
# 11.517022812366486
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 11.5170
# 2024-02-29 09:26:57,627 - utils.training_utils - INFO - Epoch 7/10
# Train:  10%|█         | 1/10 [00:01<00:12,  1.42s/train_batch]
# Epoch: [7][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.2059 Grad: 1.3270  LR: 0.00345753
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.39s/train_batch]
# Epoch: [7][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.3309 Grad: 0.7958  LR: 0.00213151
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.50valid_batch/s]
# 5.764618873596191
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 5.7646
# 3.269765168428421
# 2.5333496928215027
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.41valid_batch/s]
# 2024-02-29 09:27:11,929 - utils.training_utils - INFO - Average Training Loss: 1.3309
# 2024-02-29 09:27:11,930 - utils.training_utils - INFO - Average Validation Loss: 4.2427
# 3.4133275896310806
# 4.2427460789680485
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 4.2427
# 2024-02-29 09:27:12,201 - utils.training_utils - INFO - Epoch 8/10
# Train:  10%|█         | 1/10 [00:01<00:12,  1.42s/train_batch]
# Epoch: [8][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.2644 Grad: 1.1909  LR: 0.00199780
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.40s/train_batch]
# Epoch: [8][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.3281 Grad: 1.7468  LR: 0.00095853
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.22valid_batch/s]
# 1.033696174621582
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 1.0337
# 1.3814973831176758
# 1.4131086667378743
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.46valid_batch/s]
# 2024-02-29 09:27:26,515 - utils.training_utils - INFO - Average Training Loss: 1.3281
# 2024-02-29 09:27:26,516 - utils.training_utils - INFO - Average Validation Loss: 1.0777
# 1.2093432694673538
# 1.0777350902557372
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 1.0777
# 2024-02-29 09:27:26,788 - utils.training_utils - INFO - Epoch 9/10
# Train:  10%|█         | 1/10 [00:01<00:12,  1.42s/train_batch]
# Epoch: [9][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.1917 Grad: 1.0530  LR: 0.00086361
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.40s/train_batch]
# Epoch: [9][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.2932 Grad: 1.3568  LR: 0.00022373
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.76valid_batch/s]
# 0.9877079725265503
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 0.9877
# 1.0458396077156067
# 0.9357104500134786
# 0.9382563084363937
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.73valid_batch/s]
# 2024-02-29 09:27:41,096 - utils.training_utils - INFO - Average Training Loss: 1.2932
# 2024-02-29 09:27:41,097 - utils.training_utils - INFO - Average Validation Loss: 1.0287
# 1.0287397742271422
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 1.0287
# 2024-02-29 09:27:41,364 - utils.training_utils - INFO - Epoch 10/10
# Train:  10%|█         | 1/10 [00:01<00:12,  1.42s/train_batch]
# Epoch: [10][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.4525 Grad: 1.0795  LR: 0.00017789
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.39s/train_batch]
# Epoch: [10][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.2856 Grad: 1.3534  LR: 0.00000673
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.51valid_batch/s]
# 1.040302038192749
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 1.0403
# 1.1262266635894775
# 1.1042604843775432
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.48valid_batch/s]
# 2024-02-29 09:27:55,665 - utils.training_utils - INFO - Average Training Loss: 1.2856
# 2024-02-29 09:27:55,666 - utils.training_utils - INFO - Average Validation Loss: 1.0480
# 1.028056800365448
# 1.0479603290557862
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 1.0480

# %%
from models.custom_model_configs import BaseModelConfig


from datasets.data_loader import CustomDataset
from datasets.data_loader_configs import SmallBaseConfig
from generics import Paths
from models.CustomModel import CustomModel
from models.custom_model_configs import ShuffleNetTest, ResNetBase  
from utils.general_utils import get_logger
from utils.inference_utils import perform_inference
from utils.loader_utils import load_main_dfs
from utils.training_utils import train


class ResNetBase_LargeCF(BaseModelConfig):
    GRADIENT_ACCUMULATION_STEPS = 1
    MODEL = 'resnet50'
    FREEZE = False
    EPOCHS = 10 
    LARGE_CLASSIFIER = True

def main_testing():
    logger = get_logger("main")
    
    data_loader_config = SmallBaseConfig

    model_config = ResNetBase_LargeCF #ShuffleNetBase
    
    logger.info(f"Training model {model_config.NAME} with data loader {data_loader_config.NAME}")
    
    train_df, val_df, test_df = load_main_dfs(data_loader_config, train_val_split=(0.8, 0.2))
    
    # Load datasets
    train_dataset = CustomDataset(config=data_loader_config, main_df = train_df, mode="train", cache=True)
    val_dataset = CustomDataset(config=data_loader_config,main_df = val_df, mode="val", cache=True)
    

    # Print summaries
    train_dataset.print_summary()
    val_dataset.print_summary()


    # # Initialize and train the model
    model = CustomModel(model_config)
    train(model=model, train_dataset=train_dataset, val_dataset=val_dataset, tensorboard_prefix="shufflenet_test")

# %%
main_testing()
# Out:
# 2024-02-29 09:30:08,922 - main - INFO - Training model ResNetBase_LargeCF with data loader SmallBaseConfig
# 2024-02-29 09:30:08,922 - main - INFO - Training model ResNetBase_LargeCF with data loader SmallBaseConfig
# 2024-02-29 09:30:09,316 - data_loader.log - INFO - Loading dataset from cache: SmallBaseConfig_100_train.npz
# 2024-02-29 09:30:09,316 - data_loader.log - INFO - Loading dataset from cache: SmallBaseConfig_100_train.npz
# 2024-02-29 09:30:09,316 - data_loader.log - INFO - Loading dataset from cache: SmallBaseConfig_100_train.npz
# Train non-overlapp eeg_id shape: (17089, 12)
# 2024-02-29 09:30:09,420 - data_loader.log - INFO - Dataset loaded: train mode, 80 samples, with config SmallBaseConfig
# 2024-02-29 09:30:09,420 - data_loader.log - INFO - Dataset loaded: train mode, 80 samples, with config SmallBaseConfig
# 2024-02-29 09:30:09,420 - data_loader.log - INFO - Dataset loaded: train mode, 80 samples, with config SmallBaseConfig
# 2024-02-29 09:30:09,424 - data_loader.log - INFO - Loading dataset from cache: SmallBaseConfig_100_val.npz
# 2024-02-29 09:30:09,424 - data_loader.log - INFO - Loading dataset from cache: SmallBaseConfig_100_val.npz
# 2024-02-29 09:30:09,424 - data_loader.log - INFO - Loading dataset from cache: SmallBaseConfig_100_val.npz
# 2024-02-29 09:30:09,424 - data_loader.log - INFO - Loading dataset from cache: SmallBaseConfig_100_val.npz
# 2024-02-29 09:30:09,452 - data_loader.log - INFO - Dataset loaded: val mode, 20 samples, with config SmallBaseConfig
# 2024-02-29 09:30:09,452 - data_loader.log - INFO - Dataset loaded: val mode, 20 samples, with config SmallBaseConfig
# 2024-02-29 09:30:09,452 - data_loader.log - INFO - Dataset loaded: val mode, 20 samples, with config SmallBaseConfig
# 2024-02-29 09:30:09,452 - data_loader.log - INFO - Dataset loaded: val mode, 20 samples, with config SmallBaseConfig
# 2024-02-29 09:30:09,501 - models/models.CustomModel - INFO - Using device: cuda
# 2024-02-29 09:30:09,501 - models/models.CustomModel - INFO - Using device: cuda
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Dataset Summary:
# Mode: train
# Total Samples: 80
# Unique Patients: 80
# Unique EEGs: 80
# Unique Spectrograms: 80
# Augmentation: Disabled
# Label Distribution:
# seizure_vote    26.285294
# lpd_vote         3.955459
# gpd_vote         1.762500
# lrda_vote        6.229483
# grda_vote       14.759703
# other_vote      27.007560
# dtype: float64
#
# Vote Statistics:
#       seizure_vote  lpd_vote  gpd_vote  lrda_vote  grda_vote  other_vote
# mean      0.328566  0.049443  0.022031   0.077869   0.184496    0.337595
# var       0.200456  0.030615  0.011706   0.063723   0.138927    0.182441
# Spectrograms Loaded: 80
# EEG Spectrograms Loaded: 80
#
# Configuration Summary:
# +--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+
# | Configuration                  | Value                                                                                                                                |
# +--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+
# | APPLY_ICA_EEG_SPECTROGRAMS     | False                                                                                                                                |
# | APPLY_ICA_RAW_EEG              | False                                                                                                                                |
# | APPLY_MSPCA_EEG_SPECTROGRAMS   | False                                                                                                                                |
# | APPLY_MSPCA_RAW_EEG            | False                                                                                                                                |
# | BATCH_SIZE_TEST                | 4                                                                                                                                    |
# | BATCH_SIZE_TRAIN               | 8                                                                                                                                    |
# | BATCH_SIZE_VAL                 | 4                                                                                                                                    |
# | DROP_LAST                      | True                                                                                                                                 |
# | FEATS                          | [['Fp1', 'F7', 'T3', 'T5', 'O1'], ['Fp1', 'F3', 'C3', 'P3', 'O1'], ['Fp2', 'F8', 'T4', 'T6', 'O2'], ['Fp2', 'F4', 'C4', 'P4', 'O2']] |
# | FILTER_BY_AGREEMENT            | False                                                                                                                                |
# | FILTER_BY_AGREEMENT_MIN        | 50                                                                                                                                   |
# | FILTER_BY_AGREEMENT_ON_VAL     | False                                                                                                                                |
# | FILTER_BY_ANNOTATOR            | False                                                                                                                                |
# | FILTER_BY_ANNOTATOR_MAX        | 22                                                                                                                                   |
# | FILTER_BY_ANNOTATOR_MIN        | 7                                                                                                                                    |
# | FILTER_BY_ANNOTATOR_ON_VAL     | False                                                                                                                                |
# | NAME                           | SmallBaseConfig                                                                                                                      |
# | NAMES                          | ['LL', 'LP', 'RP', 'RR']                                                                                                             |
# | NORMALIZE_EEG_SPECTROGRAMS     | False                                                                                                                                |
# | NORMALIZE_INDIVIDUALLY         | True                                                                                                                                 |
# | NORMALIZE_RAW_EEG              | False                                                                                                                                |
# | NUM_WORKERS                    | 0                                                                                                                                    |
# | N_COMPONENTS                   | 4                                                                                                                                    |
# | PIN_MEMORY                     | True                                                                                                                                 |
# | SHUFFLE_TRAIN                  | True                                                                                                                                 |
# | SUBSET_SAMPLE_COUNT            | 100                                                                                                                                  |
# | USE_PRELOADED_EEG_SPECTROGRAMS | True                                                                                                                                 |
# | USE_PRELOADED_SPECTROGRAMS     | True                                                                                                                                 |
# | USE_WAVELET                    | None                                                                                                                                 |
# | VAL_SPLIT_RATIO                | 0.2                                                                                                                                  |
# +--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+
# Dataset Summary:
# Mode: val
# Total Samples: 20
# Unique Patients: 20
# Unique EEGs: 20
# Unique Spectrograms: 20
# Spectrograms Loaded: 20
# EEG Spectrograms Loaded: 20
#
# Configuration Summary:
# +--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+
# | Configuration                  | Value                                                                                                                                |
# +--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+
# | APPLY_ICA_EEG_SPECTROGRAMS     | False                                                                                                                                |
# | APPLY_ICA_RAW_EEG              | False                                                                                                                                |
# | APPLY_MSPCA_EEG_SPECTROGRAMS   | False                                                                                                                                |
# | APPLY_MSPCA_RAW_EEG            | False                                                                                                                                |
# | BATCH_SIZE_TEST                | 4                                                                                                                                    |
# | BATCH_SIZE_TRAIN               | 8                                                                                                                                    |
# | BATCH_SIZE_VAL                 | 4                                                                                                                                    |
# | DROP_LAST                      | True                                                                                                                                 |
# | FEATS                          | [['Fp1', 'F7', 'T3', 'T5', 'O1'], ['Fp1', 'F3', 'C3', 'P3', 'O1'], ['Fp2', 'F8', 'T4', 'T6', 'O2'], ['Fp2', 'F4', 'C4', 'P4', 'O2']] |
# | FILTER_BY_AGREEMENT            | False                                                                                                                                |
# | FILTER_BY_AGREEMENT_MIN        | 50                                                                                                                                   |
# | FILTER_BY_AGREEMENT_ON_VAL     | False                                                                                                                                |
# | FILTER_BY_ANNOTATOR            | False                                                                                                                                |
# | FILTER_BY_ANNOTATOR_MAX        | 22                                                                                                                                   |
# | FILTER_BY_ANNOTATOR_MIN        | 7                                                                                                                                    |
# | FILTER_BY_ANNOTATOR_ON_VAL     | False                                                                                                                                |
# | NAME                           | SmallBaseConfig                                                                                                                      |
# | NAMES                          | ['LL', 'LP', 'RP', 'RR']                                                                                                             |
# | NORMALIZE_EEG_SPECTROGRAMS     | False                                                                                                                                |
# | NORMALIZE_INDIVIDUALLY         | True                                                                                                                                 |
# | NORMALIZE_RAW_EEG              | False                                                                                                                                |
# | NUM_WORKERS                    | 0                                                                                                                                    |
# | N_COMPONENTS                   | 4                                                                                                                                    |
# | PIN_MEMORY                     | True                                                                                                                                 |
# | SHUFFLE_TRAIN                  | True                                                                                                                                 |
# | SUBSET_SAMPLE_COUNT            | 100                                                                                                                                  |
# | USE_PRELOADED_EEG_SPECTROGRAMS | True                                                                                                                                 |
# | USE_PRELOADED_SPECTROGRAMS     | True                                                                                                                                 |
# | USE_WAVELET                    | None                                                                                                                                 |
# | VAL_SPLIT_RATIO                | 0.2                                                                                                                                  |
# +--------------------------------+--------------------------------------------------------------------------------------------------------------------------------------+
# 2024-02-29 09:30:10,039 - models/models.CustomModel - INFO - resnet50 initialized with config ResNetBase_LargeCF
# 2024-02-29 09:30:10,039 - models/models.CustomModel - INFO - resnet50 initialized with config ResNetBase_LargeCF
# 2024-02-29 09:30:10,044 - utils.training_utils - INFO - Epoch 1/10
# Train:  10%|█         | 1/10 [00:01<00:12,  1.43s/train_batch]
# Epoch: [1][0/10] Elapsed 0m 0s (remain 0m 6s) Loss: 1.6966 Grad: 31.7080  LR: 0.00180589
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.39s/train_batch]
# Epoch: [1][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.6774 Grad: 6.2307  LR: 0.00990194
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.31valid_batch/s]
# 11544178688.0
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 11544178688.0000
# 16314557440.0
# 20354619392.0
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.35valid_batch/s]
# 2024-02-29 09:30:24,346 - utils.training_utils - INFO - Average Training Loss: 1.6774
# 2024-02-29 09:30:24,347 - utils.training_utils - INFO - Average Validation Loss: 33766488883.2000
# 24070158848.0
# 33766488883.2
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 33766488883.2000
# 2024-02-29 09:30:24,527 - utils.training_utils - INFO - Epoch 2/10
# Train:  10%|█         | 1/10 [00:01<00:12,  1.42s/train_batch]
# Epoch: [2][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.5688 Grad: 4.0565  LR: 0.00986669
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.39s/train_batch]
# Epoch: [2][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.5132 Grad: 3.1251  LR: 0.00931656
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.93valid_batch/s]
# 8012.76953125
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 8012.7695
# 6708.33056640625
# Validation:  80%|████████  | 4/5 [00:00<00:00, 14.94valid_batch/s]
# 7050.635416666667
# 6262.049560546875
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.67valid_batch/s]
# 2024-02-29 09:30:38,816 - utils.training_utils - INFO - Average Training Loss: 1.5132
# 2024-02-29 09:30:38,817 - utils.training_utils - INFO - Average Validation Loss: 5233.5103
# 5233.510327148438
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 5233.5103
# 2024-02-29 09:30:39,085 - utils.training_utils - INFO - Epoch 3/10
# Train:  10%|█         | 1/10 [00:01<00:12,  1.42s/train_batch]
# Epoch: [3][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.2433 Grad: 3.1418  LR: 0.00923078
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.39s/train_batch]
# Epoch: [3][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.4816 Grad: 2.3452  LR: 0.00826362
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.99valid_batch/s]
# 18.83871078491211
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 18.8387
# 27.189960479736328
# Validation:  80%|████████  | 4/5 [00:00<00:00, 14.98valid_batch/s]
# 26.513497670491535
# 22.840537548065186
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.89valid_batch/s]
# 2024-02-29 09:30:53,373 - utils.training_utils - INFO - Average Training Loss: 1.4816
# 2024-02-29 09:30:53,374 - utils.training_utils - INFO - Average Validation Loss: 19.2127
# 19.212670707702635
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 19.2127
# 2024-02-29 09:30:53,639 - utils.training_utils - INFO - Epoch 4/10
# Train:  10%|█         | 1/10 [00:01<00:12,  1.42s/train_batch]
# Epoch: [4][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.0583 Grad: 2.2005  LR: 0.00813663
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.39s/train_batch]
# Epoch: [4][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.4317 Grad: 3.4180  LR: 0.00685724
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.21valid_batch/s]
# 6.661375522613525
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 6.6614
# 10.009040117263794
# 10.413825511932373
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.44valid_batch/s]
# 2024-02-29 09:31:07,943 - utils.training_utils - INFO - Average Training Loss: 1.4317
# 2024-02-29 09:31:07,944 - utils.training_utils - INFO - Average Validation Loss: 12.9214
# 13.500558495521545
# 12.921446514129638
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 12.9214
# 2024-02-29 09:31:08,214 - utils.training_utils - INFO - Epoch 5/10
# Train:  10%|█         | 1/10 [00:01<00:12,  1.42s/train_batch]
# Epoch: [5][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.1827 Grad: 1.8595  LR: 0.00670279
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.39s/train_batch]
# Epoch: [5][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.4286 Grad: 3.0920  LR: 0.00524982
# Validation:  40%|████      | 2/5 [00:00<00:00, 15.03valid_batch/s]
# 26.170583724975586
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 26.1706
# 65.30332469940186
# Validation:  80%|████████  | 4/5 [00:00<00:00, 15.02valid_batch/s]
# 72.75177192687988
# 109.41806936264038
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.92valid_batch/s]
# 2024-02-29 09:31:22,508 - utils.training_utils - INFO - Average Training Loss: 1.4286
# 2024-02-29 09:31:22,508 - utils.training_utils - INFO - Average Validation Loss: 115.1254
# 2024-02-29 09:31:22,509 - utils.training_utils - INFO - Epoch 6/10
# 115.12543449401855
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 115.1254
# Train:  10%|█         | 1/10 [00:01<00:12,  1.42s/train_batch]
# Epoch: [6][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.4472 Grad: 2.8699  LR: 0.00508464
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.39s/train_batch]
# Epoch: [6][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.4852 Grad: 4.0261  LR: 0.00361554
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.93valid_batch/s]
# 4.744029521942139
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 4.7440
# 22.978469610214233
# 17.69778649012248
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.78valid_batch/s]
# 2024-02-29 09:31:36,798 - utils.training_utils - INFO - Average Training Loss: 1.4852
# 2024-02-29 09:31:36,799 - utils.training_utils - INFO - Average Validation Loss: 15.1754
# 2024-02-29 09:31:36,800 - utils.training_utils - INFO - Epoch 7/10
# 17.619449257850647
# 15.17543830871582
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 15.1754
# Train:  10%|█         | 1/10 [00:01<00:12,  1.43s/train_batch]
# Epoch: [7][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.1712 Grad: 2.3982  LR: 0.00345753
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.39s/train_batch]
# Epoch: [7][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.3339 Grad: 4.2361  LR: 0.00213151
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.53valid_batch/s]
# 1.139401912689209
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 1.1394
# 2.3374096155166626
# 2.0253796577453613
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.77valid_batch/s]
# 2024-02-29 09:31:51,097 - utils.training_utils - INFO - Average Training Loss: 1.3339
# 2024-02-29 09:31:51,098 - utils.training_utils - INFO - Average Validation Loss: 2.2103
# 2.1793273091316223
# 2.210344743728638
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 2.2103
# 2024-02-29 09:31:51,374 - utils.training_utils - INFO - Epoch 8/10
# Train:  10%|█         | 1/10 [00:01<00:12,  1.42s/train_batch]
# Epoch: [8][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.1309 Grad: 2.5623  LR: 0.00199780
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.40s/train_batch]
# Epoch: [8][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.2727 Grad: 3.0651  LR: 0.00095853
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.71valid_batch/s]
# 5.375004768371582
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 5.3750
# 3.279067039489746
# Validation:  80%|████████  | 4/5 [00:00<00:00, 14.89valid_batch/s]
# 2.617392579714457
# 2.305491030216217
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.82valid_batch/s]
# 2024-02-29 09:32:05,674 - utils.training_utils - INFO - Average Training Loss: 1.2727
# 2024-02-29 09:32:05,675 - utils.training_utils - INFO - Average Validation Loss: 2.4727
# 2024-02-29 09:32:05,676 - utils.training_utils - INFO - Epoch 9/10
# 2.4727166175842283
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 2.4727
# Train:  10%|█         | 1/10 [00:01<00:12,  1.42s/train_batch]
# Epoch: [9][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.5871 Grad: 3.8450  LR: 0.00086361
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.39s/train_batch]
# Epoch: [9][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.3170 Grad: 2.5718  LR: 0.00022373
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.35valid_batch/s]
# 1.3320937156677246
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 1.3321
# 1.360179603099823
# 1.2983380158742268
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.53valid_batch/s]
# 2024-02-29 09:32:19,982 - utils.training_utils - INFO - Average Training Loss: 1.3170
# 2024-02-29 09:32:19,983 - utils.training_utils - INFO - Average Validation Loss: 1.5680
# 1.6513314843177795
# 1.5680465698242188
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 1.5680
# 2024-02-29 09:32:20,248 - utils.training_utils - INFO - Epoch 10/10
# Train:  10%|█         | 1/10 [00:01<00:12,  1.42s/train_batch]
# Epoch: [10][0/10] Elapsed 0m 0s (remain 0m 5s) Loss: 1.2083 Grad: 2.0132  LR: 0.00017789
# Train: 100%|██████████| 10/10 [00:13<00:00,  1.39s/train_batch]
# Epoch: [10][9/10] Elapsed 0m 13s (remain 0m 0s) Loss: 1.2295 Grad: 2.7107  LR: 0.00000673
# Validation:  40%|████      | 2/5 [00:00<00:00, 14.83valid_batch/s]
# 1.6439177989959717
# EVAL: [0/5] Elapsed 0m 0s (remain 0m 0s) Loss: 1.6439
# 1.4511905312538147
# 1.396728515625
# Validation: 100%|██████████| 5/5 [00:00<00:00, 14.81valid_batch/s]
# 2024-02-29 09:32:34,546 - utils.training_utils - INFO - Average Training Loss: 1.2295
# 2024-02-29 09:32:34,547 - utils.training_utils - INFO - Average Validation Loss: 1.6187
# 1.5382703840732574
# 1.6187129735946655
# EVAL: [4/5] Elapsed 0m 0s (remain 0m 0s) Loss: 1.6187
